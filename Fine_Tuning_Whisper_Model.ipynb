# %% [markdown]
# <a href="https://colab.research.google.com/github/bacoco/LLM_train/blob/main/Fine_Tuning_Whisper_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip3 install git+https://github.com/promptslab/LLMTuner

# %%
from llmtuner import Tuner, Dataset, Model

# Initialize the Whisper model
model = Model("openai/whisper-small")

# Create a dataset instance for the audio files
dataset = Dataset(dummy_data= True, type_ = 'half')
# Out:
# ...
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 4361it [00:00, 62119.16it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 2179it [00:00, 67391.67it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 2894it [00:00, 71412.36it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 3328it [00:00, 67804.84it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 680it [00:00, 64906.62it/s]

# %%
# Set up the tuner with the model and dataset for fine-tuning
tuner = Tuner(model, dataset)

# Fine-tune the model
trained_model = tuner.fit()
# Out:
# ...
# Map (num_proc=2):   0%|          | 0/5 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 01:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
# ...

# %%
# Inference with Fine-tuned model
tuner.inference('/content/ad.wav')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-24e114521811> in <cell line: 2>()
#       1 # Inference with Fine-tuned model
# ----> 2 tuner.inference('/content/ad.wav')
#
# /usr/local/lib/python3.10/dist-packages/llmtuner/tuner/whisper_tuner.py in inference(self, audio_file, language_abbr)
#      46                                              self.model_.task,
#      47                                              self.model_.use_peft)
# ---> 48         return transcription_pipeline.transcribe(audio_file)
#      49
#      50     def wer_eval(self, split, language_abbr = 'hi'):
#
# ...

# %%
# Launch an interactive UI for the fine-tuned model
tuner.launch_ui('hi')
